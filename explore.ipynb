# %%
import requests as req

# %%
url = "https://api.openfigi.com/v3/search?query=fhs"

r = req.get(url)
# data = r.json()


print(r)
# Out:
# <Response [405]>

# %%
import requests, pandas as pd


# load in this file to get the list of companies on the ASX
FILEURL = "https://www.asx.com.au/asx/research/ASXListedCompanies.csv"

df = pd.read_csv(FILEURL, skiprows=2)
df["ASX code"].to_list()
# Out:
# ['14D',
#  '29M',
#  'T3D',
#  'TGP',
#  'TCF',
#  'TOT',
#  'TDO',
#  '3PL',
#  '4DX',
#  '4DS',
#  '5EA',
#  '5GN',
#  '88E',
#  '8CO',
#  '8IH',
#  '8VI',
#  'AYI',
#  'ABG',
#  'ASK',
#  'ABX',
#  'AKG',
#  'AX8',
#  'AX1',
#  'ACS',
#  'ADC',
#  'ACQ',
#  'ACF',
#  'ACR',
#  'ACW',
#  'ATV',
#  'AIV',
#  'ACU',
#  'ACE',
#  'AD1',
#  'ADA',
#  'ADH',
#  '1AD',
#  'ADD',
#  'ADG',
#  'ADR',
#  'AI1',
#  'ADY',
#  'ABY',
#  'AHL',
#  'ADT',
#  'ADS',
#  'AVM',
#  'ANO',
#  'ABV',
#  'AHI',
#  'AV1',
#  'ADX',
#  'AER',
#  'AML',
#  'AEI',
#  'AIS',
#  'AMX',
#  'AFL',
#  'AF3',
#  'AFT',
#  'A1G',
#  'AFP',
#  'AGL',
#  'AMN',
#  'AGR',
#  'AIM',
#  'A1M',
#  'APW',
#  'AGI',
#  'AIZ',
#  'ART',
#  'AJL',
#  'AKO',
#  'AUQ',
#  'ALB',
#  'ALY',
#  'ALC',
#  'AAI',
#  'AL8',
#  'ARN',
#  'AJX',
#  'AAL',
#  '1AI',
#  'AQI',
#  'AQX',
#  'ALK',
#  'AMT',
#  'AQZ',
#  'AXN',
#  'AGE',
#  'APS',
#  'ALM',
#  'AII',
#  'A4N',
#  'ALQ',
#  'ALR',
#  'AZI',
#  'ATC',
#  'ATH',
#  'AIQ',
# ...
